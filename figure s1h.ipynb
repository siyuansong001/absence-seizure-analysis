# %%
import scanpy as sc
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import glob
import anndata
import sys
from scipy.io import mmread
sys.path.append(r'/media/data2/samba/xjlab/')

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# 2025-04-02 17:15:34.830206: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-02 17:15:35.872492: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# scanpy==1.9.3 anndata==0.10.5.post1 umap==0.5.3 numpy==1.24.4 scipy==1.13.1 pandas==2.2.2 scikit-learn==1.3.0 statsmodels==0.14.1 python-igraph==0.10.6 louvain==0.7.1 pynndescent==0.5.6

# %%
adata = anndata.read_h5ad('/media/data2/samba/ssong/data/Developmental somatosensory/done/P4.h5ad')

# %%
sc.pl.umap(adata, color='Arpp21', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, save='Arpp21.svg', vmin=1.5, vmax=2.2)
# Out:
# WARNING: saving figure to file figures/umapArpp21.svg

# %%
sc.pl.umap(adata, color='Satb2', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, save='Satb2.svg')
# Out:
# WARNING: saving figure to file figures/umapSatb2.svg

# %%
sc.pl.umap(adata, color='Gad1', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd)

# %%
sc.pl.umap(adata, color='Gad2', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd)

# %%
sc.pl.umap(adata, color='Elmo1', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, vmin=1.5)

# %%
sc.pl.umap(adata, color='Igfbp4', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, vmin=1.5)

# %%
sc.pl.umap(adata, color='Sst', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, save='Sst.svg', vmin=2.1, vmax=2.5)
# Out:
# WARNING: saving figure to file figures/umapSst.svg

# %%
sc.pl.umap(adata, color='Htr3a', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd)

# %%
sc.pl.umap(adata, color='Vip', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd)

# %%
sc.pl.umap(adata, color='Cxcl14', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, save='Cxcl14.svg')
# Out:
# WARNING: saving figure to file figures/umapCxcl14.svg

# %%
sc.pl.umap(adata, color='Mef2c', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, vmin=2.6)

# %%
sc.pl.umap(adata, color='Erbb4', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, vmin=1.5)

# %%
sc.pl.umap(adata, color='Plcxd3', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, vmin=1.1)

# %%
sc.pl.umap(adata, color='Nxph1', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, save='Nxph1.svg', vmin=1.2)
# Out:
# WARNING: saving figure to file figures/umapNxph1.svg

# %%
sc.pl.umap(adata, color='Nxph2', size=8, legend_loc='on data', legend_fontsize=8, palette="Set2", color_map=plt.cm.OrRd, save='Nxph2.svg', vmin=1.2)
# Out:
# WARNING: saving figure to file figures/umapNxph2.svg
